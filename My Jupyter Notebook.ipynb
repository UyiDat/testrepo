# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Osamuyimen Idah**
#
#   Financial Consultant

# %% [markdown]
# *I am interested in data science because it provides me essential tools necessary for enhancing my effectiveness and productivity in my career as a financial consultant.*

# %% [markdown]
# ### My code in cell 5 is meant to calculate the sum of two and three

# %%
2 + 3
# Out:
# 5

# %% [markdown]
# [Google link](https://www.google.com/)
#
# Here's a large IBM logo: ![ibm-logo.jpg](attachment:ibm-logo.jpg)
#
# > This is a blockquote.
